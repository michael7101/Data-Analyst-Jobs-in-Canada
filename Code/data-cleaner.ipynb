# %%
# Required python packages:
import pandas as pd
import re
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# %%
# Importing datasets:
df = pd.read_csv("Jobs.csv")

# %%
df1 = df.drop(['error', 'timestamp', 'query','companyUrl','applicantsCount',
               'viewsCount','appliesClosedAt', 'companyLogoUrl', 'applyUrl', 
               'jobState', 'jobPosterProfileUrl', 'jobPosterName','hiringManager', 
               'coverLetter', 'pipeLine', 'mySkills', 'skillsCount','excel', 
               'tableau', 'python', 'sql', 'power bi', 'R', 'google sheets',
               'qgis', 'appDate','remoteAllowed'], axis=1)

# %%
# converts all the text in the column 'jobDescription' to lowercase letters
df1['jobDescription'] = df1['jobDescription'].str.lower()

# %%
# print the column names
print(df1.columns)
# Out:
# Index(['companyName', 'jobTitle', 'jobLocation', 'postedAt', 'jobDescription',
#        'jobId', 'workplaceType', 'experienceLevel', 'companyStaffCount',
#        'companyDescription', 'jobIndustries', 'jobFunctions', 'jobType'],
#       dtype='object')

# %%
import pandas as pd

def find_keywords(series, keywords):
    # create a new column to store the keywords
    keywords_col = pd.Series('', index=series.index)
    # loop through each row in the column
    for i, text in series.iteritems():
        # check for null values
        if text is not None and not pd.isnull(text):
            row_keywords = []
            # loop through each keyword
            for keyword in keywords:
                if keyword in text:
                    # if the keyword is in the text, add it to the list of row_keywords
                    row_keywords.append(keyword)
            # join the row_keywords list into a string and add it to the 'keywords' column
            keywords_col.at[i] = ', '.join(row_keywords)
    return keywords_col

# %%
keywords = ['excel', 'tableau', 'python', ' sql', 'power bi', ' r ', 'google sheets', 'qgis'
           ' asw', ' azure', 'snowflake', 'redshift', 'databricks', ' oracle', ' gcp', 'bigquery'
           ' java ', 'scala', ' sas ', 'nosql', '', 'javescript', 'c++', 'c#'
           ' c ', 'html', ' word ', 'sql servr', 'mysql', ' spark ', 'hadoop', 'kafka']

df1['keywords'] = find_keywords(df1['jobDescription'], keywords)

# %%
def print_unique_keywords(df1):
    unique_keywords = df1['keywords'].unique()
    for keyword in unique_keywords:
        print(keyword)

# %%
df1
# Out:
#                                    companyName  \
# 0                                        Agoda
# 1     iA Financial Group (Industrial Alliance)
# 2                               Point S Canada
# 3                                          BRP
# 4                             Societe Generale
# ...                                        ...
# 2006                                      BGIS
# 2007                                BOMBARDIER
# 2008                                    Beneva
# 2009                                     Appen
# 2010                                       BRP
#
#                                                jobTitle  \
# 0     Senior Data Analyst, Partner Development – (St...
# 1                   Analyste en intelligence d'affaires
# 2                                   Analyste de données
# 3                                Logistics Data Analyst
# 4                                  Quantitative Analyst
# ...                                                 ...
# 2006                           chargé de projet adjoint
# 2007  Professional, Engineering – Avionics Supplier ...
# 2008            Chargé de projets – conducteur de train
# 2009                     Video Data Collection - Remote
# 2010  Ingénieur senior en développement de systèmes ...
#
#                         jobLocation                  postedAt  \
# 0                     Vancouver, BC  2022-11-23T04:55:18.000Z
# 1                        Québec, QC  2022-11-17T11:05:59.000Z
# 2                  Boucherville, QC  2022-11-24T06:13:05.000Z
# 3                      Valcourt, QC  2022-12-03T16:21:48.000Z
# 4              Greater Montreal, QC  2022-12-01T12:44:54.000Z
# ...                             ...                       ...
# 2006                     Ottawa, ON  2023-03-22T17:13:32.000Z
# 2007                   Montreal, QC  2023-03-20T11:32:07.000Z
# 2008                     Québec, QC  2023-03-25T00:44:43.000Z
# 2009  Northwest Territories, Canada  2023-03-20T22:40:30.000Z
# 2010                   Valcourt, QC  2023-03-20T10:44:05.000Z
#
#                                          jobDescription       jobId  \
# 0     about agoda\nagoda is an online travel booking...  3368318779
# 1     vous souhaitez joindre une équipe dynamique et...  3327891315
# 2     type d'emploi : temps plein, permanent\nbouche...  3366347623
# 3     why join the team?\nto experience exciting cha...  3385841439
# 4     responsibilities\nthe quantitative advisor wil...  3322489093
# ...                                                 ...         ...
# 2006  job description\n\nà propos de bgis \n\nbgis e...  3539192709
# 2007  bombardier\nbombardier is a global leader, cre...  3471448670
# 2008  titre d'emploi:\n\nchargé de projets – conduct...  3542646833
# 2009  help improve ai technology for facial recognit...  3530233741
# 2010  pourquoi se joindre à l’équipe? \npour mettre ...  3320965461
#
#      workplaceType experienceLevel  companyStaffCount  \
# 0              NaN       Associate             5732.0
# 1           Hybrid       Associate             7455.0
# 2          On-site     Entry level               61.0
# 3          On-site     Entry level             6909.0
# 4           Hybrid     Entry level            47107.0
# ...            ...             ...                ...
# 2006       On-site     Entry level             4945.0
# 2007        Hybrid     Entry level            28790.0
# 2008        Hybrid     Entry level             4282.0
# 2009        Remote     Entry level            17996.0
# 2010       On-site     Entry level             7334.0
#
#                                      companyDescription  \
# 0     Agoda is transforming travel for millions of c...
# 1     iA Financial Group is one of the largest insur...
# 2     Point S Canada is the country’s largest networ...
# 3     We create innovative ways to move – on snow, o...
# 4     Societe Generale is one of the leading Europea...
# ...                                                 ...
# 2006  BGIS is a global leader in the provision of Fa...
# 2007  Bombardier is a global leader in aviation, foc...
# 2008  Beneva, c’est unir nos valeurs mutualistes pou...
# 2009  We help our clients enhance their best-in-clas...
# 2010  We create innovative ways to move – on snow, o...
#
#                                jobIndustries  \
# 0                                   Internet
# 1              Financial Services, Insurance
# 2                                 Automotive
# 3                             Consumer Goods
# 4     Financial Services, Investment Banking
# ...                                      ...
# 2006                     Facilities Services
# 2007                    Aviation & Aerospace
# 2008                               Insurance
# 2009       Information Technology & Services
# 2010                          Consumer Goods
#
#                                    jobFunctions    jobType  \
# 0                        Information Technology  Full-time
# 1               Analyst, Information Technology  Full-time
# 2                        Information Technology  Full-time
# 3                        Information Technology  Full-time
# 4     Research, Analyst, Information Technology  Full-time
# ...                                         ...        ...
# 2006                  Management, Manufacturing  Full-time
# 2007                  Management, Manufacturing  Full-time
# 2008                  Management, Manufacturing  Full-time
# 2009  Information Technology, Analyst, Research  Part-time
# 2010        Engineering, Information Technology  Full-time
#
#                                                keywords
# 0     excel, tableau, python,  sql, power bi,  r , s...
# 1                                       sql, power bi,
# 2                               excel,  sql, power bi,
# 3                                     excel, power bi,
# 4                                  excel, python, , c++
# ...                                                 ...
# 2006                                            excel,
# 2007                                            excel,
# 2008
# 2009
# 2010                                            excel,
#
# [2011 rows x 14 columns]
